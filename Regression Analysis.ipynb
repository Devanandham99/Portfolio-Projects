# %%
import numpy as np
import pandas as pd
import statsmodels.api as sm
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
import seaborn as sns
sns.set()

# %% [markdown]
# # Upload Data

# %%
rawdata=pd.read_csv("C:/Users/DevanandamRSV/Python/Test data/Sample data.csv")
#rawdata.head()
# Out:
# C:\Users\DevanandamRSV\AppData\Local\Temp\ipykernel_26956\1209194142.py:1: DtypeWarning: Columns (0,6,7,9,12,13,14,15,17,18,19,20) have mixed types. Specify dtype option on import or set low_memory=False.
#   rawdata=pd.read_csv("C:/Users/DevanandamRSV/Python/Test data/Sample data.csv")

# %% [markdown]
# ## Pre Processing

# %%
rawdata.describe(include='all')
# Out:
# count    65534.000000
# mean         6.713888
# std         12.931898
# min          0.000000
# 25%          0.000000
# 50%          3.990000
# 75%          9.990000
# max        999.980000
# Name: price_initial (USD), dtype: float64

# %%
rawdata['price_initial (USD)'] = rawdata['price_initial (USD)'].apply(lambda x: np.nan if isinstance(x, str) else x)
rawdata=rawdata.dropna(subset=['price_initial (USD)'])
rawdata.describe(include='all')
#sns.distplot(rawdata['price_initial (USD)'])
rawdata.to_csv("C:/Users/DevanandamRSV/Python/Test data/Sample op.csv")

# %%
rawdata['release_date']=pd.to_datetime(rawdata["release_date"], errors='coerce')
rawdata.head()
# Out:
# C:\Users\DevanandamRSV\AppData\Local\Temp\ipykernel_26956\1461150317.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   rawdata['release_date']=pd.to_datetime(rawdata["release_date"], errors='coerce')
#   steam_appid                    name           developers  \
# 0     2719590           Light No Fire      ['Hello Games']
# 1     2719600    Lorhaven: Cursed War  ['GoldenGod Games']
# 2     2719610            PUIQ: Demons          ['Giammnn']
# 3     2719650          Project XSTING      ['Saucy Melon']
# 4     2719670  The Milgram Experiment    ['Theseus Games']
#
#             publishers                                         categories  \
# 0      ['Hello Games']  ['Single-player', 'Multi-player', 'Co-op', 'On...
# 1  ['GoldenGod Games']  ['Single-player', 'Multi-player', 'PvP', 'Shar...
# ...

# %%
rawdata.isnull().sum()
# Out:
# steam_appid               0
# name                      0
# developers                0
# publishers                0
# categories                0
# genres                    0
# required_age              0
# n_achievements            0
# platforms                 0
# is_released               0
# release_date           8456
# additional_content        0
# total_reviews             2
# total_positive            2
# total_negative            2
# review_score              2
# review_score_desc         2
# positive_percentual       2
# metacritic                2
# is_free                   2
# price_initial (USD)       2
# dtype: int64

# %%
rawdata=rawdata.dropna(axis=0)
rawdata.isnull().sum()
# Out:
# steam_appid            0
# name                   0
# developers             0
# publishers             0
# categories             0
# genres                 0
# required_age           0
# n_achievements         0
# platforms              0
# is_released            0
# release_date           0
# additional_content     0
# total_reviews          0
# total_positive         0
# total_negative         0
# review_score           0
# review_score_desc      0
# positive_percentual    0
# metacritic             0
# is_free                0
# price_initial (USD)    0
# dtype: int64

# %%
rawdata.describe(include='all')
# Out:
#         steam_appid      name developers publishers  \
# count       30206.0     30206      30206      30206
# unique      30206.0     30127      22497      20065
# top       2719600.0  Arboreal         []         []
# freq            1.0         3        104        251
# mean            NaN       NaN        NaN        NaN
# min             NaN       NaN        NaN        NaN
# 25%             NaN       NaN        NaN        NaN
# 50%             NaN       NaN        NaN        NaN
# 75%             NaN       NaN        NaN        NaN
# max             NaN       NaN        NaN        NaN
#
#                                  categories               genres  \
# count                                 30206                30206
# unique                                 3343                 1485
# top     ['Single-player', 'Family Sharing']  ['Casual', 'Indie']
# freq                                   6974                 1799
# ...
