# %%
import numpy as np
import pandas as pd
import statsmodels.api as sm
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# %%
rawdata=pd.read_csv("steam_games.csv")
#rawdata.head()

# %%
rawdata.describe(include='all')
# Out:
#          steam_appid    name developers publishers  \
# count   7.142900e+04   71429      71429      71429
# unique           NaN   70990      49545      44187
# top              NaN  Aurora         []         []
# freq             NaN       4        200        493
# mean    1.613700e+06     NaN        NaN        NaN
# std     8.625559e+05     NaN        NaN        NaN
# min     7.300000e+02     NaN        NaN        NaN
# 25%     9.296400e+05     NaN        NaN        NaN
# 50%     1.533470e+06     NaN        NaN        NaN
# 75%     2.383530e+06     NaN        NaN        NaN
# max     3.430140e+06     NaN        NaN        NaN
#
#                                  categories               genres  \
# count                                 71429                71429
# unique                                 6995                 2373
# top     ['Single-player', 'Family Sharing']  ['Action', 'Indie']
# freq                                  12030                 3914
# ...

# %%
rawdata['price_initial (USD)'] = rawdata['price_initial (USD)'].apply(lambda x: np.nan if isinstance(x, str) else x)
rawdata=rawdata.dropna(subset=['price_initial (USD)'])
rawdata.describe(include='all')
#sns.distplot(rawdata['price_initial (USD)'])
rawdata.to_csv("steam_games op.csv")

# %%
rawdata['release_date']=pd.to_datetime(rawdata["release_date"], errors='coerce')
rawdata.head()
# Out:
#    steam_appid                  name           developers  \
# 0      2719580              勇者の伝説の勇者             ['ぽけそう']
# 1      2719590         Light No Fire      ['Hello Games']
# 2      2719600  Lorhaven: Cursed War  ['GoldenGod Games']
# 3      2719610          PUIQ: Demons          ['Giammnn']
# 4      2719650        Project XSTING      ['Saucy Melon']
#
#             publishers                                         categories  \
# 0             ['ぽけそう']                ['Single-player', 'Family Sharing']
# 1      ['Hello Games']  ['Single-player', 'Multi-player', 'Co-op', 'On...
# 2  ['GoldenGod Games']  ['Single-player', 'Multi-player', 'PvP', 'Shar...
# 3          ['Giammnn']  ['Single-player', 'Steam Achievements', 'Famil...
# 4      ['Saucy Melon']  ['Single-player', 'Steam Achievements', 'Steam...
#
#                                           genres  required_age  \
# 0                            ['Casual', 'Indie']             0
# ...

# %%
rawdata.isnull().sum()
# Out:
# steam_appid                0
# name                       0
# developers                 0
# publishers                 0
# categories                 0
# genres                     0
# required_age               0
# n_achievements             0
# platforms                  0
# is_released                0
# release_date           71401
# additional_content         0
# total_reviews              0
# total_positive             0
# total_negative             0
# review_score               0
# review_score_desc          0
# positive_percentual        0
# metacritic                 0
# is_free                    0
# price_initial (USD)        0
# dtype: int64

# %%
rawdata=rawdata.dropna(axis=0)
rawdata.isnull().sum()
# Out:
# steam_appid            0
# name                   0
# developers             0
# publishers             0
# categories             0
# genres                 0
# required_age           0
# n_achievements         0
# platforms              0
# is_released            0
# release_date           0
# additional_content     0
# total_reviews          0
# total_positive         0
# total_negative         0
# review_score           0
# review_score_desc      0
# positive_percentual    0
# metacritic             0
# is_free                0
# price_initial (USD)    0
# dtype: int64

# %%
rawdata.describe(include='all')
# Out:
#          steam_appid      name developers publishers  \
# count   2.800000e+01        28         28         28
# unique           NaN        28         28         28
# top              NaN  勇者の伝説の勇者   ['ぽけそう']   ['ぽけそう']
# freq             NaN         1          1          1
# mean    2.719634e+06       NaN        NaN        NaN
# min     2.719130e+06       NaN        NaN        NaN
# 25%     2.719298e+06       NaN        NaN        NaN
# 50%     2.719680e+06       NaN        NaN        NaN
# 75%     2.719928e+06       NaN        NaN        NaN
# max     2.720070e+06       NaN        NaN        NaN
# std     3.131009e+02       NaN        NaN        NaN
#
#                                  categories               genres  \
# count                                    28                   28
# unique                                   16                   22
# top     ['Single-player', 'Family Sharing']  ['Casual', 'Indie']
# ...
